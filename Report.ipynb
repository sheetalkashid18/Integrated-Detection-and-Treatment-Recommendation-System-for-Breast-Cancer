# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import glob
from PIL import Image, ImageFilter, ImageOps
from scipy.stats import kurtosis, skew

# %%
img1 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample010.jpg")
img2 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample101.jpg")
img3 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample124.jpg")
img4 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample052.jpg")
img5 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample181.jpg")
img6 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample238.jpg")
img7 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample130.jpg")
img8 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample030.jpg")
img9 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample005.jpg")
img10 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample205.jpg")
img11 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample183.jpg")
img12 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample198.jpg")
img13 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample025.jpg")
img14 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample092.jpg")
img15 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample099.jpg")
img16 = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/WOPectoralNew/sample005.jpg")

# %%
plt.imshow(img16)

# %%
center_coordinates1 = (502, 863) 
radius1 = 44
color1 = (0, 0, 255) 
thickness = 10
center_coordinates2 = (500, 856) 
radius2 = 26
color2 = (255, 0, 0) 
thickness = 10
img16 = cv2.circle(img16, center_coordinates1, radius1, color1, thickness)
img16 = cv2.circle(img16, center_coordinates2, radius2, color2, thickness)

# %%
plt.imshow(img16)
