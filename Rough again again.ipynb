# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import glob
from PIL import Image, ImageFilter, ImageOps

# %%
img = cv2.imread("C:/Users/devda/Major/Data/all-mias/JPEG/Tumors/tumor001.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
img = cv2.circle(img, (535, 599), 197, (255, 255, 255),  5)

# %%
img = cv2.circle(img, (500, 856), 26, (0, 0, 0),  5)
